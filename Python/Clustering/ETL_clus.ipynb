# %%
# for basic mathematics operation 
import numpy as np
import pandas as pd

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

from yellowbrick.cluster import SilhouetteVisualizer
import random

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "none"

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_excel("../energy_prod_def.xlsx")

# %%
list = ["emission_factor", "biofuel_share_elec", "coal_share_elec", "fossil_share_elec", "gas_share_elec", 
        "hydro_share_elec", "low_carbon_share_elec", "nuclear_share_elec", "oil_share_elec", 
        "solar_share_elec", "wind_share_elec"]

# %%
df1_filtered = df1[list]

df1_filtered.columns = ['emission_factor', 'biofuel', "coal", "fossil", "gas", 
        "hydro", "low_carbon", "nuclear", "oil", 
        "solar", "wind"]

df1_filtered.to_excel('clustering_df.xlsx', index=False)

# %%
df2 = df1_filtered

# %%
df2 = pd.read_excel("clustering_df.xlsx")

# %%
from sklearn.preprocessing import MinMaxScaler

# Applicare MinMaxScaler
scaler = MinMaxScaler() # type: ignore
df2[df2.columns] = scaler.fit_transform(df2[df2.columns])
df2.to_excel('clustering_df.xlsx', index=False)

# %%
raw_data=pd.read_excel("clustering_df.xlsx")
raw_data

# %%
pd.set_option('display.width', 160)
print(df2)
# Out:
#       emission_factor   biofuel      coal    fossil      gas     hydro  low_carbon   nuclear       oil     solar      wind
# 0            0.323374  0.035833  0.505273  0.794207  0.20824  0.170537    0.205793  0.037174  0.137185  0.000115  0.001361
# 1            0.350765  0.035369  0.496981  0.794759  0.21978  0.175632    0.205241  0.029399  0.133173  0.000115  0.003177
# 2            0.364485  0.040941  0.485591  0.794338  0.23777  0.174326    0.205662  0.030987  0.123442  0.000115  0.003142
# 3            0.361395  0.038465  0.492029  0.805921  0.24355  0.161875    0.194079  0.031339  0.123007  0.000115  0.003631
# 4            0.364787  0.038078  0.485054  0.806192  0.26115  0.161011    0.193808  0.031188  0.109276  0.000229  0.004922
# ...               ...       ...       ...       ...      ...       ...         ...       ...       ...       ...       ...
# 1076         0.636306  0.159430  0.399446  0.646482  0.23474  0.159051    0.353518  0.126908  0.043152  0.124828  0.167673
# ...

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# Calcola la matrice di correlazione
matrice_correlazione = df2.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(matrice_correlazione, annot=True, cmap="Greens", annot_kws={"size": 9})
plt.title("Matrice di Correlazione")
plt.show()

# %%
sns.pairplot(df2)
plt.show()
